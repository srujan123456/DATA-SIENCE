# %% [markdown]
# <a href="https://colab.research.google.com/github/srujan123456/DATA-SIENCE/blob/ANOTHER/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(1,40,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show(np)
